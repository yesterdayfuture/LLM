# %% [markdown]
# ### deepspeed 单机多卡训练模型

# %% [markdown]
# ### 相关环境
# #### 1、系统环境

# %% [markdown]
# ![image.png](attachment:7a4168e6-149c-43d3-bc13-7127ed202562.png)
# ![image.png](attachment:e9d78a7e-c102-4d90-bd48-20fc062d75d1.png)

# %% [markdown]
# #### 2、安装相关库

# %%
# !pip install torch torchvision matplotlib
# !pip install deepspeed argparse

# %% [markdown]
# ### 运行显卡占用
# ![image.png](attachment:ffa0a5fe-be60-4646-a240-17ef08abd43e.png)
